# %% [markdown]
# # Raw-only UCI Heart Disease MLOps Notebook
#
# This notebook belongs to the raw-only version of the assignment. Data acquisition uses the original unprocessed UCI 76-attribute files (`cleveland.data`, `hungarian.data`, `switzerland.data`, and `long-beach-va.data`). The `processed.*` files are not used for model development. The pipeline extracts the 14 documented ML variables directly from raw records and converts the original `num` target into a binary classification label.

# %% [markdown]
# This notebook calls the production training script. Metrics and artifacts are logged to MLflow.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()))
from src.train import main as train
train()
# Out:
# 2026-07-08 07:36:09,989 | INFO | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-08 07:36:09,993 | INFO | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026/07/08 07:36:12 INFO mlflow.tracking.fluent: Experiment with name 'heart-disease-risk-prediction-mlops-raw-76-only' does not exist. Creating a new experiment.
# 2026-07-08 07:36:12,653 | INFO | Training LogisticRegression
# 2026/07/08 07:36:19 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026-07-08 07:36:19,586 | INFO | Training RandomForestClassifier
# 2026/07/08 07:36:25 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026-07-08 07:36:25,140 | INFO | Training SupportVectorMachine
# c:\Users\ASUS\MLOPS\mlops-heart-disease-v3\.venv\Lib\site-packages\sklearn\svm\_base.py:239: FutureWarning: The `probability` parameter was deprecated in 1.9 and will be removed in version 1.11. Use `CalibratedClassifierCV(SVC(), ensemble=False)` instead of `SVC(probability=True)`
#   warnings.warn(
# 2026/07/08 07:36:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2026-07-08 07:36:28,609 | INFO | Saved final model to C:\Users\ASUS\MLOPS\mlops-heart-disease-v3\models\final_model.joblib
# 2026-07-08 07:36:28,610 | INFO | Saved metadata to C:\Users\ASUS\MLOPS\mlops-heart-disease-v3\models\model_metadata.json
# 2026-07-08 07:36:28,611 | INFO | Best model: RandomForestClassifier

# %%
import pandas as pd
pd.read_csv("../models/model_comparison.csv" if Path.cwd().name == "notebooks" else "models/model_comparison.csv")
# Out:
#                     model                                        best_params  \
# 0  RandomForestClassifier  {"classifier__max_depth": 6, "classifier__min_...
# 1    SupportVectorMachine  {"classifier__C": 2.0, "classifier__kernel": "...
# 2      LogisticRegression  {"classifier__C": 0.1, "classifier__solver": "...
#
#    best_cv_roc_auc  accuracy  precision    recall        f1   roc_auc
# 0         0.887248  0.846154   0.834862  0.900990  0.866667  0.906980
# 1         0.888115  0.818681   0.809091  0.881188  0.843602  0.906246
# 2         0.874222  0.802198   0.803738  0.851485  0.826923  0.899646
